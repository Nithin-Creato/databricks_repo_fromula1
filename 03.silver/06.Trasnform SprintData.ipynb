# %% [markdown]
# - Read bronze circuits table
# - Keep only the columns required for analytics.
# - standardise column names using snake_case.
# - Concatenate name.givename and family name to create a new column called driver_name and transform the values to tile case.
# - Filer out rows where circuit_id is null
# - Remobe duplicate records.
# - Transform values of columns circuit_name and locality to Title case
# - write the trandformed data to silver circuits table

# %%
# %run ../00.Common/01.environment-config

# %%
bronze_table = f"{catalog_nameone}.{bronze_schema}.sprints"
silver_table = f"{catalog_nameone}.{silver_schema}.sprints"

# %%
from pyspark.sql import functions as F

# %%
sprints_df = spark.read.table(bronze_table)

# %%
from pyspark.sql.functions import col

sprints_dropped_df = sprints_df.drop(F.col("url"))

# %%
sprints_renamed_df = (
  sprints_dropped_df
    .withColumnsRenamed({
      "constructorId": "constructor_Id",
      "driverId": "driver_Id",
      "raceName": "race_Name",
      "date": "race_date",
      "grid": "grid_position",
      "laps": "completed_laps",
      "number": "car_number",
      "position": "final_position",
      "positionText": "final_position_text"
    })
)

# %%
sprints_valid_df = (
    sprints_renamed_df
        .filter(
            F.col("season").isNotNull() &
            F.col("round").isNotNull() &
            F.col("driver_Id").isNotNull() &
            F.col("constructor_Id").isNotNull()
        )
)

# %%
sprints_distinct_df = sprints_valid_df.dropDuplicates(["season", "round", "driver_Id", "constructor_Id"])

# %%
display(sprints_renamed_df.count() - sprints_valid_df.count())

# %%
sprints_final_df = (
    sprints_distinct_df
        .withColumn('race_name', F.initcap(F.col("race_Name")))
)

# %%
sprints_final_df.write.format("delta").mode("overwrite").saveAsTable(silver_table)

# %%
display(spark.read.table(silver_table))
