# %%
catalog_name = 'formula1'
catalog_nameone = 'devfromula1'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'

# %%
landing_folder_path = '/Volumes/devfromula1/spark_db/datasets/'
